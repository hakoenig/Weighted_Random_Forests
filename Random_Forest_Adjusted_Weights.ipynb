# %%
import copy
import types
import numpy as np
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score as sklearn_accuracy_score

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def get_accuracy(classifier, X_test, y_test):
    """
    Calculating overall accuracy for classifier.
    """
    predictions = classifier.predict(X_test)
    
    return sklearn_accuracy_score(y_test, predictions)


def calculate_weights_for_trees(self, X_train, y_train):
    """
    Method to calculate trees' weights.
    """
    # calculating weights for each tree
    self.tree_weights = np.array([get_accuracy(estimator, X_train, y_train) 
                                         for estimator in self.estimators_])
    # ensuring that weights sum to one
    self.tree_weights = self.tree_weights / self.tree_weights.sum()
    

def predict_with_weights(self, X_test, X_train, y_train):
    """
    Method for weighted RF instance to leverage trees' weights.
    """
    #first, check if weights are already defined
    if not hasattr(self, 'tree_weights'):
        self.calculate_weights_for_trees(X_train, y_train)
    
    #getting raw predictions from trees
    raw_predictions = np.array([estimator.predict_proba(X_test)[:,1] for estimator in self.estimators_])
    #weighing raw predictions with trees' weights
    return np.sum(raw_predictions.T * self.tree_weights, axis=1)

# %%
results = []

# %%
n_samples = [500, 1000, 10000, 50000, 100000]
n_features = [5, 10, 50]
n_estimators = [25, 50, 100, 500]
max_depth = [1, 5, 10]

# %%
for samples in n_samples:
    for n_feature in n_features:
        for n_estimator in n_estimators:
            for depth in max_depth:
                
                print("Working on:", '-'.join([str(x) for x in (samples, n_feature, n_estimator, depth)]))
                
                X, y = make_classification(n_samples=samples, n_features=n_feature)
                
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
                
                standard_rf = RandomForestClassifier(n_estimators=n_estimator, 
                                                     max_depth=depth, 
                                                     n_jobs=-1,
                                                     random_state=np.random.randint(1, 1000000))
                _ = standard_rf.fit(X_train, y_train)

                standard_accuracy = get_accuracy(standard_rf, X_test, y_test)
                print("Standard RF achieves accuracy of: ", standard_accuracy)
                
                # Getting a copy of RF instance that we can manipulate
                weighted_rf = copy.deepcopy(standard_rf)

                # Adding functions to copied RF instance
                weighted_rf.calculate_weights_for_trees = types.MethodType(calculate_weights_for_trees, weighted_rf)
                weighted_rf.predict_with_weights = types.MethodType(predict_with_weights, weighted_rf)
                
                weighted_predictions = weighted_rf.predict_with_weights(X_test, X_train, y_train)

                # Turning weighted scores into 1s and 0s for sklearn accuracy
                weighted_predictions[np.greater(weighted_predictions, 0.5)] = 1
                weighted_predictions[weighted_predictions < 1] = 0

                weighted_accuracy = sklearn_accuracy_score(y_test, weighted_predictions)
                
                results.append([samples, n_feature, n_estimator, depth, standard_accuracy, weighted_accuracy])

results_df = pd.DataFrame(data=results,
                          columns=['n_samples', 'n_features', 
                                   'n_estimators', 'max_depth', 
                                   'accuracy_standard', 'accuracy_weighted'])
# Out:
# Working on: 500-5-25-1
# Standard RF achieves accuracy of:  0.909090909091
# Working on: 500-5-25-5
# Standard RF achieves accuracy of:  0.933333333333
# Working on: 500-5-25-10
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 500-5-50-1
# Standard RF achieves accuracy of:  0.878787878788
# Working on: 500-5-50-5
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 500-5-50-10
# Standard RF achieves accuracy of:  0.927272727273
# Working on: 500-5-100-1
# Standard RF achieves accuracy of:  0.90303030303
# Working on: 500-5-100-5
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 500-5-100-10
# Standard RF achieves accuracy of:  0.915151515152
# Working on: 500-5-500-1
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 500-5-500-5
# Standard RF achieves accuracy of:  0.939393939394
# Working on: 500-5-500-10
# Standard RF achieves accuracy of:  0.89696969697
# Working on: 500-10-25-1
# Standard RF achieves accuracy of:  0.915151515152
# Working on: 500-10-25-5
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 500-10-25-10
# Standard RF achieves accuracy of:  0.927272727273
# Working on: 500-10-50-1
# Standard RF achieves accuracy of:  0.89696969697
# Working on: 500-10-50-5
# Standard RF achieves accuracy of:  0.884848484848
# Working on: 500-10-50-10
# Standard RF achieves accuracy of:  0.933333333333
# Working on: 500-10-100-1
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 500-10-100-5
# Standard RF achieves accuracy of:  0.866666666667
# Working on: 500-10-100-10
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 500-10-500-1
# Standard RF achieves accuracy of:  0.890909090909
# Working on: 500-10-500-5
# Standard RF achieves accuracy of:  0.957575757576
# Working on: 500-10-500-10
# Standard RF achieves accuracy of:  0.939393939394
# Working on: 500-50-25-1
# Standard RF achieves accuracy of:  0.890909090909
# Working on: 500-50-25-5
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 500-50-25-10
# Standard RF achieves accuracy of:  0.884848484848
# Working on: 500-50-50-1
# Standard RF achieves accuracy of:  0.848484848485
# Working on: 500-50-50-5
# Standard RF achieves accuracy of:  0.878787878788
# Working on: 500-50-50-10
# Standard RF achieves accuracy of:  0.781818181818
# Working on: 500-50-100-1
# Standard RF achieves accuracy of:  0.969696969697
# Working on: 500-50-100-5
# Standard RF achieves accuracy of:  0.830303030303
# Working on: 500-50-100-10
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 500-50-500-1
# Standard RF achieves accuracy of:  0.921212121212
# Working on: 500-50-500-5
# Standard RF achieves accuracy of:  0.884848484848
# Working on: 500-50-500-10
# Standard RF achieves accuracy of:  0.878787878788
# Working on: 1000-5-25-1
# Standard RF achieves accuracy of:  0.839393939394
# Working on: 1000-5-25-5
# Standard RF achieves accuracy of:  0.972727272727
# Working on: 1000-5-25-10
# Standard RF achieves accuracy of:  0.966666666667
# Working on: 1000-5-50-1
# Standard RF achieves accuracy of:  0.872727272727
# Working on: 1000-5-50-5
# Standard RF achieves accuracy of:  0.954545454545
# Working on: 1000-5-50-10
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 1000-5-100-1
# Standard RF achieves accuracy of:  0.912121212121
# Working on: 1000-5-100-5
# Standard RF achieves accuracy of:  0.942424242424
# Working on: 1000-5-100-10
# Standard RF achieves accuracy of:  0.942424242424
# Working on: 1000-5-500-1
# Standard RF achieves accuracy of:  0.90303030303
# Working on: 1000-5-500-5
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 1000-5-500-10
# Standard RF achieves accuracy of:  0.90303030303
# Working on: 1000-10-25-1
# Standard RF achieves accuracy of:  0.9
# Working on: 1000-10-25-5
# Standard RF achieves accuracy of:  0.890909090909
# Working on: 1000-10-25-10
# Standard RF achieves accuracy of:  0.948484848485
# Working on: 1000-10-50-1
# Standard RF achieves accuracy of:  0.915151515152
# Working on: 1000-10-50-5
# Standard RF achieves accuracy of:  0.915151515152
# Working on: 1000-10-50-10
# Standard RF achieves accuracy of:  0.9
# Working on: 1000-10-100-1
# Standard RF achieves accuracy of:  0.927272727273
# Working on: 1000-10-100-5
# Standard RF achieves accuracy of:  0.969696969697
# Working on: 1000-10-100-10
# Standard RF achieves accuracy of:  0.848484848485
# Working on: 1000-10-500-1
# Standard RF achieves accuracy of:  0.90303030303
# Working on: 1000-10-500-5
# Standard RF achieves accuracy of:  0.966666666667
# Working on: 1000-10-500-10
# Standard RF achieves accuracy of:  0.854545454545
# Working on: 1000-50-25-1
# Standard RF achieves accuracy of:  0.921212121212
# Working on: 1000-50-25-5
# Standard RF achieves accuracy of:  0.978787878788
# Working on: 1000-50-25-10
# Standard RF achieves accuracy of:  0.863636363636
# Working on: 1000-50-50-1
# Standard RF achieves accuracy of:  0.981818181818
# Working on: 1000-50-50-5
# Standard RF achieves accuracy of:  0.887878787879
# Working on: 1000-50-50-10
# Standard RF achieves accuracy of:  0.930303030303
# Working on: 1000-50-100-1
# Standard RF achieves accuracy of:  0.878787878788
# Working on: 1000-50-100-5
# Standard RF achieves accuracy of:  0.921212121212
# Working on: 1000-50-100-10
# Standard RF achieves accuracy of:  0.957575757576
# Working on: 1000-50-500-1
# Standard RF achieves accuracy of:  0.857575757576
# Working on: 1000-50-500-5
# Standard RF achieves accuracy of:  0.924242424242
# Working on: 1000-50-500-10
# Standard RF achieves accuracy of:  0.984848484848
# Working on: 10000-5-25-1
# Standard RF achieves accuracy of:  0.954848484848
# Working on: 10000-5-25-5
# Standard RF achieves accuracy of:  0.963939393939
# Working on: 10000-5-25-10
# Standard RF achieves accuracy of:  0.972424242424
# Working on: 10000-5-50-1
# Standard RF achieves accuracy of:  0.917878787879
# Working on: 10000-5-50-5
# Standard RF achieves accuracy of:  0.958787878788
# Working on: 10000-5-50-10
# Standard RF achieves accuracy of:  0.937272727273
# Working on: 10000-5-100-1
# Standard RF achieves accuracy of:  0.939090909091
# Working on: 10000-5-100-5
# Standard RF achieves accuracy of:  0.924242424242
# Working on: 10000-5-100-10
# Standard RF achieves accuracy of:  0.924545454545
# Working on: 10000-5-500-1
# Standard RF achieves accuracy of:  0.942727272727
# Working on: 10000-5-500-5
# Standard RF achieves accuracy of:  0.93696969697
# Working on: 10000-5-500-10
# Standard RF achieves accuracy of:  0.951212121212
# Working on: 10000-10-25-1
# Standard RF achieves accuracy of:  0.863636363636
# Working on: 10000-10-25-5
# Standard RF achieves accuracy of:  0.886666666667
# Working on: 10000-10-25-10
# Standard RF achieves accuracy of:  0.908484848485
# Working on: 10000-10-50-1
# Standard RF achieves accuracy of:  0.890303030303
# Working on: 10000-10-50-5
# Standard RF achieves accuracy of:  0.91696969697
# Working on: 10000-10-50-10
# Standard RF achieves accuracy of:  0.943333333333
# Working on: 10000-10-100-1
# Standard RF achieves accuracy of:  0.871818181818
# Working on: 10000-10-100-5
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 10000-10-100-10
# Standard RF achieves accuracy of:  0.894545454545
# Working on: 10000-10-500-1
# Standard RF achieves accuracy of:  0.876363636364
# Working on: 10000-10-500-5
# Standard RF achieves accuracy of:  0.948181818182
# Working on: 10000-10-500-10
# Standard RF achieves accuracy of:  0.968484848485
# Working on: 10000-50-25-1
# Standard RF achieves accuracy of:  0.914242424242
# Working on: 10000-50-25-5
# Standard RF achieves accuracy of:  0.951515151515
# Working on: 10000-50-25-10
# Standard RF achieves accuracy of:  0.950606060606
# Working on: 10000-50-50-1
# Standard RF achieves accuracy of:  0.854848484848
# Working on: 10000-50-50-5
# Standard RF achieves accuracy of:  0.919393939394
# Working on: 10000-50-50-10
# Standard RF achieves accuracy of:  0.98
# Working on: 10000-50-100-1
# Standard RF achieves accuracy of:  0.854848484848
# Working on: 10000-50-100-5
# Standard RF achieves accuracy of:  0.942727272727
# Working on: 10000-50-100-10
# Standard RF achieves accuracy of:  0.899090909091
# Working on: 10000-50-500-1
# Standard RF achieves accuracy of:  0.869090909091
# Working on: 10000-50-500-5
# Standard RF achieves accuracy of:  0.912424242424
# Working on: 10000-50-500-10
# Standard RF achieves accuracy of:  0.941515151515
# Working on: 50000-5-25-1
# Standard RF achieves accuracy of:  0.928727272727
# Working on: 50000-5-25-5
# Standard RF achieves accuracy of:  0.962303030303
# Working on: 50000-5-25-10
# Standard RF achieves accuracy of:  0.913757575758
# Working on: 50000-5-50-1
# Standard RF achieves accuracy of:  0.854909090909
# Working on: 50000-5-50-5
# Standard RF achieves accuracy of:  0.923575757576
# Working on: 50000-5-50-10
# Standard RF achieves accuracy of:  0.897939393939
# Working on: 50000-5-100-1
# Standard RF achieves accuracy of:  0.943393939394
# Working on: 50000-5-100-5
# Standard RF achieves accuracy of:  0.945454545455
# Working on: 50000-5-100-10
# Standard RF achieves accuracy of:  0.893454545455
# Working on: 50000-5-500-1
# Standard RF achieves accuracy of:  0.809212121212
# Working on: 50000-5-500-5
# Standard RF achieves accuracy of:  0.893696969697
# Working on: 50000-5-500-10
# Standard RF achieves accuracy of:  0.976303030303
# Working on: 50000-10-25-1
# Standard RF achieves accuracy of:  0.966121212121
# Working on: 50000-10-25-5
# Standard RF achieves accuracy of:  0.927575757576
# Working on: 50000-10-25-10
# Standard RF achieves accuracy of:  0.992242424242
# Working on: 50000-10-50-1
# Standard RF achieves accuracy of:  0.882121212121
# Working on: 50000-10-50-5
# Standard RF achieves accuracy of:  0.884666666667
# Working on: 50000-10-50-10
# Standard RF achieves accuracy of:  0.937151515152
# Working on: 50000-10-100-1
# Standard RF achieves accuracy of:  0.82703030303
# Working on: 50000-10-100-5
# Standard RF achieves accuracy of:  0.950848484848
# Working on: 50000-10-100-10
# Standard RF achieves accuracy of:  0.914363636364
# Working on: 50000-10-500-1
# Standard RF achieves accuracy of:  0.882606060606
# Working on: 50000-10-500-5
# Standard RF achieves accuracy of:  0.99103030303
# Working on: 50000-10-500-10
# Standard RF achieves accuracy of:  0.987696969697
# Working on: 50000-50-25-1
# Standard RF achieves accuracy of:  0.945212121212
# Working on: 50000-50-25-5
# Standard RF achieves accuracy of:  0.920060606061
# Working on: 50000-50-25-10
# Standard RF achieves accuracy of:  0.940121212121
# Working on: 50000-50-50-1
# Standard RF achieves accuracy of:  0.901757575758
# Working on: 50000-50-50-5
# Standard RF achieves accuracy of:  0.893636363636
# Working on: 50000-50-50-10
# Standard RF achieves accuracy of:  0.953090909091
# Working on: 50000-50-100-1
# Standard RF achieves accuracy of:  0.942242424242
# Working on: 50000-50-100-5
# Standard RF achieves accuracy of:  0.929212121212
# Working on: 50000-50-100-10
# Standard RF achieves accuracy of:  0.962666666667
# Working on: 50000-50-500-1
# Standard RF achieves accuracy of:  0.843454545455
# Working on: 50000-50-500-5
# Standard RF achieves accuracy of:  0.905515151515
# Working on: 50000-50-500-10
# Standard RF achieves accuracy of:  0.926606060606
# Working on: 100000-5-25-1
# Standard RF achieves accuracy of:  0.913818181818
# Working on: 100000-5-25-5
# Standard RF achieves accuracy of:  0.96403030303
# Working on: 100000-5-25-10
# Standard RF achieves accuracy of:  0.924363636364
# Working on: 100000-5-50-1
# Standard RF achieves accuracy of:  0.907484848485
# Working on: 100000-5-50-5
# Standard RF achieves accuracy of:  0.923515151515
# Working on: 100000-5-50-10
# Standard RF achieves accuracy of:  0.929303030303
# Working on: 100000-5-100-1
# Standard RF achieves accuracy of:  0.944636363636
# Working on: 100000-5-100-5
# Standard RF achieves accuracy of:  0.949909090909
# Working on: 100000-5-100-10
# Standard RF achieves accuracy of:  0.929575757576
# Working on: 100000-5-500-1
# Standard RF achieves accuracy of:  0.926090909091
# Working on: 100000-5-500-5
# Standard RF achieves accuracy of:  0.972424242424
# Working on: 100000-5-500-10
# Standard RF achieves accuracy of:  0.970484848485
# Working on: 100000-10-25-1
# Standard RF achieves accuracy of:  0.953454545455
# Working on: 100000-10-25-5
# Standard RF achieves accuracy of:  0.947787878788
# Working on: 100000-10-25-10
# Standard RF achieves accuracy of:  0.981787878788
# Working on: 100000-10-50-1
# Standard RF achieves accuracy of:  0.884666666667
# Working on: 100000-10-50-5
# Standard RF achieves accuracy of:  0.958939393939
# Working on: 100000-10-50-10
# Standard RF achieves accuracy of:  0.909636363636
# Working on: 100000-10-100-1
# Standard RF achieves accuracy of:  0.970909090909
# Working on: 100000-10-100-5
# Standard RF achieves accuracy of:  0.951666666667
# Working on: 100000-10-100-10
# Standard RF achieves accuracy of:  0.896181818182
# Working on: 100000-10-500-1
# Standard RF achieves accuracy of:  0.925303030303
# Working on: 100000-10-500-5
# Standard RF achieves accuracy of:  0.927545454545
# Working on: 100000-10-500-10
# Standard RF achieves accuracy of:  0.932636363636
# Working on: 100000-50-25-1
# Standard RF achieves accuracy of:  0.898363636364
# Working on: 100000-50-25-5
# Standard RF achieves accuracy of:  0.895666666667
# Working on: 100000-50-25-10
# Standard RF achieves accuracy of:  0.939696969697
# Working on: 100000-50-50-1
# Standard RF achieves accuracy of:  0.893939393939
# Working on: 100000-50-50-5
# Standard RF achieves accuracy of:  0.865545454545
# Working on: 100000-50-50-10
# Standard RF achieves accuracy of:  0.921606060606
# Working on: 100000-50-100-1
# Standard RF achieves accuracy of:  0.903575757576
# Working on: 100000-50-100-5
# Standard RF achieves accuracy of:  0.891090909091
# Working on: 100000-50-100-10
# Standard RF achieves accuracy of:  0.911575757576
# Working on: 100000-50-500-1
# Standard RF achieves accuracy of:  0.937151515152
# Working on: 100000-50-500-5
# Standard RF achieves accuracy of:  0.959060606061
# Working on: 100000-50-500-10
# Standard RF achieves accuracy of:  0.946878787879

# %%
results_df
# Out:
#      n_samples  n_features  n_estimators  max_depth  accuracy_standard  \
# 0          500           5            25          1           0.909091
# 1          500           5            25          5           0.933333
# 2          500           5            25         10           0.951515
# 3          500           5            50          1           0.878788
# 4          500           5            50          5           0.951515
# 5          500           5            50         10           0.927273
# 6          500           5           100          1           0.903030
# 7          500           5           100          5           0.951515
# 8          500           5           100         10           0.915152
# 9          500           5           500          1           0.951515
# 10         500           5           500          5           0.939394
# 11         500           5           500         10           0.896970
# 12         500          10            25          1           0.915152
# 13         500          10            25          5           0.945455
# 14         500          10            25         10           0.927273
# 15         500          10            50          1           0.896970
# 16         500          10            50          5           0.884848
# 17         500          10            50         10           0.933333
# 18         500          10           100          1           0.945455
# 19         500          10           100          5           0.866667
# 20         500          10           100         10           0.945455
# 21         500          10           500          1           0.890909
# 22         500          10           500          5           0.957576
# 23         500          10           500         10           0.939394
# 24         500          50            25          1           0.890909
# 25         500          50            25          5           0.951515
# 26         500          50            25         10           0.884848
# 27         500          50            50          1           0.848485
# 28         500          50            50          5           0.878788
# 29         500          50            50         10           0.781818
# ..         ...         ...           ...        ...                ...
# 150     100000           5           100          1           0.944636
# 151     100000           5           100          5           0.949909
# 152     100000           5           100         10           0.929576
# 153     100000           5           500          1           0.926091
# 154     100000           5           500          5           0.972424
# 155     100000           5           500         10           0.970485
# 156     100000          10            25          1           0.953455
# 157     100000          10            25          5           0.947788
# 158     100000          10            25         10           0.981788
# 159     100000          10            50          1           0.884667
# 160     100000          10            50          5           0.958939
# 161     100000          10            50         10           0.909636
# 162     100000          10           100          1           0.970909
# 163     100000          10           100          5           0.951667
# 164     100000          10           100         10           0.896182
# 165     100000          10           500          1           0.925303
# 166     100000          10           500          5           0.927545
# 167     100000          10           500         10           0.932636
# 168     100000          50            25          1           0.898364
# 169     100000          50            25          5           0.895667
# 170     100000          50            25         10           0.939697
# 171     100000          50            50          1           0.893939
# 172     100000          50            50          5           0.865545
# 173     100000          50            50         10           0.921606
# 174     100000          50           100          1           0.903576
# 175     100000          50           100          5           0.891091
# 176     100000          50           100         10           0.911576
# 177     100000          50           500          1           0.937152
# 178     100000          50           500          5           0.959061
# 179     100000          50           500         10           0.946879
#
#      accuracy_weighted
# 0             0.909091
# 1             0.933333
# 2             0.951515
# 3             0.866667
# 4             0.951515
# 5             0.927273
# 6             0.884848
# 7             0.951515
# 8             0.915152
# 9             0.951515
# 10            0.939394
# 11            0.896970
# 12            0.915152
# 13            0.945455
# 14            0.927273
# 15            0.884848
# 16            0.884848
# 17            0.933333
# 18            0.939394
# 19            0.866667
# 20            0.945455
# 21            0.890909
# 22            0.957576
# 23            0.939394
# 24            0.890909
# 25            0.945455
# 26            0.884848
# 27            0.854545
# 28            0.878788
# 29            0.775758
# ..                 ...
# 150           0.944545
# 151           0.949909
# 152           0.929576
# 153           0.926333
# 154           0.972424
# 155           0.970485
# 156           0.953455
# 157           0.947758
# 158           0.981788
# 159           0.888515
# 160           0.958848
# 161           0.909636
# 162           0.970879
# 163           0.951667
# 164           0.896212
# 165           0.924606
# 166           0.927545
# 167           0.932636
# 168           0.898212
# 169           0.896152
# 170           0.939697
# 171           0.894364
# 172           0.865697
# 173           0.921576
# 174           0.905848
# 175           0.891091
# 176           0.911636
# 177           0.918697
# 178           0.958909
# 179           0.946818
#
# [180 rows x 6 columns]

# %%
results_df['diff_improvement'] = results_df['accuracy_weighted'] - results_df['accuracy_standard']
results_df.to_csv('results_df.csv')

# %%
#Overall mean of improvement
results_df['diff_improvement'].mean() * 100
# Out:
# -0.0706734006734003

# %%
#Mean of improvement when grouped by grid search params
col_list = ['n_samples', 'n_features', 'n_estimators', 'max_depth']

for col in col_list:
    results_df.groupby([col])['diff_improvement'].mean() * 100
# Out:
# n_samples
# 500      -0.151515
# 1000      0.008418
# 10000    -0.029461
# 50000    -0.129293
# 100000   -0.051515
# Name: diff_improvement, dtype: float64
# n_features
# 5    -0.084747
# 10   -0.049192
# 50   -0.078081
# Name: diff_improvement, dtype: float64
# n_estimators
# 25     0.009832
# 50    -0.068215
# 100   -0.163636
# 500   -0.060673
# Name: diff_improvement, dtype: float64
# max_depth
# 1    -0.182020
# 5    -0.016061
# 10   -0.013939
# Name: diff_improvement, dtype: float64
